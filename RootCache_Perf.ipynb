# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

width = .35 # width of a bar

# 1M Searches - Pure Randomised 
# Shows significant improvement until cache size of 2K
# Baseline Iterated Levels: 12000000 (12 Levels)
# Max Iterations Saved (2K Cache Size) - 26.715 % Iterations Saved
m1_t = pd.DataFrame({
 'baseline' : [1, 1, 1, 1, 1, 1, 1],
 'iterated_levels' : [0.999986167,0.9630743,0.93407134,0.893579834,0.84463075,0.790406,0.73284925],
 'hit_rate' : [0.0056,61.9207,77.9543,88.0176,93.8519,97.0544,98.628100]})

m1_t[['iterated_levels']].plot(kind='bar', color='green', width = width)
m1_t['baseline'].plot(kind='line', marker='*', color='white', ms=10)

ax = plt.gca()
plt.xlim([-width, len(m1_t['hit_rate'])-width])
ax.set_xticklabels(('1', '64', '128', '256', '512', '1024', '2048'))

plt.show()

# %%
width = .35 # width of a bar

# 1M Searches - Skewed Randomiseds Test Case 1 
# Random Key Set: 10% 
# Sequential Key Set: 90%
# Shows significant improvement until cache size of 64
# sequential dominant searches witha definite regular pattern show high effectiveness of root cache
# Maximum Improvement can be observed to be: 67.77 % Iterations saved over the baseline
# Baseline Iterated Levels: 12000000 (12 Levels)

m1_t = pd.DataFrame({
 'baseline' : [1, 1, 1, 1, 1, 1, 1],
 'iterated_levels' : [0.5249985,0.49937233,0.35671175,0.3396859167,0.3286525,0.32433391, 0.32254925],
 'hit_rate' : [60.0002,90.254400,87.187400,88.477100,91.3948,93.833,95.812]})

m1_t[['iterated_levels']].plot(kind='bar', color='orange', width = width)
m1_t['baseline'].plot(kind='line', marker='*', color='white', ms=10)

ax = plt.gca()
plt.xlim([-width, len(m1_t['hit_rate'])-width])
ax.set_xticklabels(('1', '2', '4', '8', '16', '32', '64'))

plt.show()

# %%
width = .35 # width of a bar

# 1M Searches - Skewed Randomiseds Test Case 1 
# Random Key Set: 30% 
# Sequential Key Set: 70%
# Shows significant improvement until cache size of 64
# sequential dominant searches with a definite regular pattern show high effectiveness of root cache
# Maximum Improvement can be observed to be: 53.51 % Iterations saved over the baseline
# Baseline Iterated Levels: 12000000 (12 Levels)

m1_t = pd.DataFrame({
 'baseline' : [1, 1, 1, 1, 1, 1, 1],
 'iterated_levels' : [0.6305495833,0.6149975833,0.499485833,0.4852854167,0.4756310833,0.4701686667, 0.4648529167],
 'hit_rate' : [46.6682,70.7947,68.5643,71.8896,76.6213,82.2732,88.2453]})

m1_t[['iterated_levels']].plot(kind='bar', color='blue', width = width)
m1_t['baseline'].plot(kind='line', marker='*', color='white', ms=10)

ax = plt.gca()
plt.xlim([-width, len(m1_t['hit_rate'])-width])
ax.set_xticklabels(('1', '2', '4', '8', '16', '32', '64'))

plt.show()

# %%
width = .35 # width of a bar

# 1M Searches - Skewed Randomiseds Test Case 1 
# Random Key Set: 60% 
# Sequential Key Set: 30%
# Shows significant improvement until cache size of 2K
# Here the cache size needed to view good performance improvement drastically changes.
# sequential dominant searches with a definite regular pattern show high effectiveness of root cache
# Maximum Improvement can be observed to be: 46.03 % Iterations saved over the baseline
# Baseline Iterated Levels: 12000000 (12 Levels)

m1_t = pd.DataFrame({
 'baseline' : [1, 1, 1, 1, 1, 1, 1],
 'iterated_levels' : [0.7888803,0.67831525,0.66051675,0.632105833,0.60682433,0.5742464167, 0.5396734167],
 'hit_rate' : [26.6695,77.0156,86.769300,92.7806,96.2867,98.2156,99.15530]})

m1_t[['iterated_levels']].plot(kind='bar', color='green', width = width)
m1_t['baseline'].plot(kind='line', marker='*', color='white', ms=10)

ax = plt.gca()
plt.xlim([-width, len(m1_t['hit_rate'])-width])
ax.set_xticklabels(('1', '64', '128', '256', '512', '1024', '2048'))

plt.show()

# %%
width = .35 # width of a bar

# 1M Searches - Skewed Randomiseds Test Case 1 
# Random Key Set: 90% 
# Sequential Key Set: 10%
# Shows significant improvement until cache size of 2K
# Here the cache size needed to view good performance improvement drastically changes.
# sequential dominant searches with a definite regular pattern show high effectiveness of root cache
# Maximum Improvement can be observed to be: 31.54275 % Iterations saved over the baseline
# Baseline Iterated Levels: 12000000 (12 Levels)

m1_t = pd.DataFrame({
 'baseline' : [1, 1, 1, 1, 1, 1, 1],
 'iterated_levels' : [0.9077124167,0.89188425,0.8657494167,0.8293314167,0.7852409167,0.7364350833, 0.68457925],
 'hit_rate' : [47.63100,65.648100,80.183900,92.7806,94.459,97.2964,98.7746]})

m1_t[['iterated_levels']].plot(kind='bar', color='orange', width = width)
m1_t['baseline'].plot(kind='line', marker='*', color='white', ms=10)

ax = plt.gca()
plt.xlim([-width, len(m1_t['hit_rate'])-width])
ax.set_xticklabels(('32', '64', '128', '256', '512', '1024', '2048'))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Node Size: 5 (degree 3)
# height of the tree: 12
# 7^8 = 5,764,801 (smallest pair to satisfy proportional node size to depth)
# Search Space: 1 Million Searches (1/3 Sequential, 1/3 40% Random Skewed, 1/3 Random)
# cache size: 256 Entries
#frequency plot
x = [0, 266793, 178079, 89838, 42239, 24520, 29011, 59146, 106522, 107547, 57179, 39126]
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))


plt.hist(y)
plt.show()
# Out:
# <class 'list'>

# %%
import matplotlib.pyplot as plt
import numpy as np
# frequency plot
# cache size: 1024
# purely random: 
x = [0, 296, 816, 2266, 6758, 20078, 55869, 141921, 264355, 268114, 142078, 97749]
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))


plt.hist(y)
plt.show()
# Out:
# <class 'list'>

# %%
# degree 7
# B Tree height 10 (Closest we can bring it to)
import matplotlib.pyplot as plt
import numpy as np
# frequency plot
# cache size: 64
# Workload: Sequential, 60% Skewed Random, Sequential
# Levels Saved : 6754165 Levels iterated in total (32.46 % Levels Saved)
x = [0, 225018, 112562, 42416, 14945, 6952, 14437, 50057, 157303, 376310]
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))


plt.hist(y)
plt.show()
# Out:
# <class 'list'>

# %%
# Root Cache Final Result Compilation

# %%
# No of elements: 1000000
# degree: 5 (9 Nodes)
# Levels: 9
# Purely Random
# Levels Saved: 26.4 %
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


y = np.array([918, 4190, 20360, 93026, 317689, 395863, 126130, 41824])
Levels = ["2", "3", "4", "5", "6", "7", "8", "9"]

plt.pie(y, labels = Levels)
plt.show()

# %%
# degree 5 (Node Size 9)
# B Tree height 9 
import matplotlib.pyplot as plt
import numpy as np
# frequency plot
# cache size: 1024
# Workload: Purely Random
# Levels Saved : 26.4% Levels Saved
m1_t = pd.DataFrame({
 'baseline' : [1, 1, 1, 1, 1, 1, 1]})
x = np.array([0, 918, 4190, 20360, 93026, 317689, 395863, 126130, 41824, 0])
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))

plt.hist(y)
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
# No of elements: 1000000
# degree: 5 (9 Nodes)
# Levels: 9
# 90% random
# Levels Saved: 31.02 %
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


y = np.array([64883, 29370, 26171, 86178, 287307, 355211, 113276, 37604])
Levels = ["2", "3", "4", "5", "6", "7", "8", "9"]

plt.pie(y, labels = Levels)
plt.show()

# %%
# degree 5 (Node Size 9)
# B Tree height 9 
import matplotlib.pyplot as plt
import numpy as np
# frequency plot
# cache size: 1024
# Workload: Purely Random
# Levels Saved : 31.02 %
m1_t = pd.DataFrame({
 'baseline' : [1, 1, 1, 1, 1, 1, 1]})
x = np.array([0, 64883, 29370, 26171, 86178, 287307, 355211, 113276, 37604, 0])
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))

plt.hist(y)
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
# No of elements: 1000000
# degree: 5 (9 Nodes)
# Levels: 9
# 80% random
# Levels Saved: 35.58 %
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


y = np.array([128736, 54478, 31532, 78725, 256042, 316904, 100023, 33560])
Levels = ["2", "3", "4", "5", "6", "7", "8", "9"]

plt.pie(y, labels = Levels)
plt.show()

# %%
# degree 5 (Node Size 9)
# B Tree height 9 
import matplotlib.pyplot as plt
import numpy as np
# frequency plot
# cache size: 1024
# Workload: 80% Random
# Levels Saved : 35.58 %
x = np.array([0, 128736, 54478, 31532, 78725, 256042, 316904, 100023, 33560, 0])
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))

plt.hist(y)
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
# No of elements: 1000000
# degree: 5 (9 Nodes)
# Levels: 9
# 60% random
# Levels Saved: 44.74 %
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


y = np.array([256603, 104903, 42712, 64398, 193122, 237451, 75624, 25187])
Levels = ["2", "3", "4", "5", "6", "7", "8", "9"]

plt.pie(y, labels = Levels)
plt.show()

# %%
# degree 5 (Node Size 9)
# B Tree height 9 
import matplotlib.pyplot as plt
import numpy as np
# frequency plot
# cache size: 1024
# Workload: 60% Random
# Levels Saved : 44.74 %
x = np.array([0, 256603, 104903, 42712, 64398, 193122, 237451, 75624, 25187, 0])
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))

plt.hist(y)
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
# No of elements: 1000000
# degree: 5 (9 Nodes)
# Levels: 9
# 40% random
# Levels Saved: 53.91 %
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


y = np.array([384379, 155311, 54053, 49799, 130681, 158457, 50510, 16810])
Levels = ["2", "3", "4", "5", "6", "7", "8", "9"]

plt.pie(y, labels = Levels)
plt.show()

# %%
# degree 5 (Node Size 9)
# B Tree height 9 
import matplotlib.pyplot as plt
import numpy as np
# frequency plot
# cache size: 1024
# Workload: 40% Random
# Levels Saved : 53.91 %
x = [0, 384379, 155311, 54053, 49799, 130681, 158457, 50510, 16810, 0]
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))

plt.hist(y)
plt.show()
# Out:
# <class 'list'>

# %%
# No of elements: 1000000
# degree: 5 (9 Nodes)
# Levels: 9
# 20% random
# Levels Saved: 63.05 %
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


y = np.array([512190, 205630, 65573, 34856, 67810, 80100, 25336, 8505])
Levels = ["2", "3", "4", "5", "6", "7", "8", "9"]

plt.pie(y, labels = Levels)
plt.show()

# %%
# degree 5 (Node Size 9)
# B Tree height 9 
import matplotlib.pyplot as plt
import numpy as np
# frequency plot
# cache size: 1024
# Workload: 20% Random
# Levels Saved : 63.05 %
x = [0, 512190, 205630, 65573, 34856, 67810, 80100, 25336, 8505, 0]
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))

plt.hist(y)
plt.show()
# Out:
# <class 'list'>

# %%
# No of elements: 1000000
# degree: 5 (9 Nodes)
# Levels: 9
# Ordered
# Levels Saved: 72.22 %
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


y = np.array([640004, 256000, 76800, 20480, 5120, 1224, 240, 132])
Levels = ["2", "3", "4", "5", "6", "7", "8", "9"]

plt.pie(y, labels = Levels)
plt.show()

# %%
# degree 5 (Node Size 9)
# B Tree height 9 
import matplotlib.pyplot as plt
import numpy as np
# frequency plot
# cache size: 1024
# Workload: Ordered
# Levels Saved : 72.22 %
x = [0, 640004, 256000, 76800, 20480, 5120, 1224, 240, 132, 0]
y = []
for i in range(len(x)):
    for j in range(x[i]):
        y.append(i)
print(type(x))

plt.hist(y)
plt.show()
# Out:
# <class 'list'>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

width = .35 # width of a bar

m1_t = pd.DataFrame({
 'baseline' : [1, 1, 1, 1, 1, 1, 1],
 'iterated_levels' : [0.734,0.6892,0.6442,0.5526,0.4609,0.3695,0.2778],
 'Address Based Cache' : [0.67,0.67,0.67,0.67,0.67,0.67,0.67]})

m1_t[['iterated_levels']].plot(kind='bar', color='green', width = width)
# m1_t['baseline'].plot(kind='line', marker='*', color='white', ms=10)
m1_t['Address Based Cache'].plot(kind='line', marker='x', color='white', ms=10)

ax = plt.gca()
plt.xlim([-width, len(m1_t['Address Based Cache'])-width])
ax.set_xticklabels(('R 1', 'R 0.9', 'R 0.8', 'R 0.6', 'R 0.4', 'R 0.2', 'O'))

plt.show()
